# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
twitch_vs_game_data_df = pd.read_csv('Resources/merge_output.csv')
twitch_vs_game_data_df.head()
# Out:
#                      title  avg_hours_watched  avg_hours_streamed  \
# 0  .hack//G.U. Last Recode             145350               35258
# 1     20 Minutes Till Dawn             911356               12253
# 2              60 Parsecs!             529688                1867
# 3              60 Seconds!             314900                1023
# 4            7 Days to Die            1023033               89486
#
#    avg_streamers  avg_viewers  avg_channels   app_id release_date  \
# 0           3174          202            49   525480   2017-11-03
# 1           3616         1267            17  1966900   2023-06-08
# 2            606          736             2   646270   2018-09-18
# 3            420          424             0   368360   2015-05-25
# 4           8880         1397           122   251570   2013-12-13
#
#    reviews_total  review_avg_percent  launch_price_cents  \
# 0           2689                87.0                4999
# 1          20942                92.0                 499
# 2           2315                89.0                 999
# 3           9979                84.0                 899
# 4         185945                88.0                2499
#
#    dataset_est_rev_cents
# 0               13442311
# 1               10450058
# 2                2312685
# 3                8971121
# 4              464676555

# %%
twitch_vs_game_data_df['avg_hours_watched'].sort_values()
# Out:
# 340       93954
# 290       95776
# 708       99303
# 120       99531
# 562      100594
#          ...
# 233    28608284
# 198    42350161
# 128    48489362
# 127    53172684
# 302    64115728
# Name: avg_hours_watched, Length: 862, dtype: int64

# %% [markdown]
# 7| twitch data for engagement and product promotion | Ryan MadO
# 8| twitch viewer count to review count correlation x=review_count y=viewer_count size=revenue | Ryan MadO
# 9| twitch viewer count by tag/genre. interactible, select from top 30-50(?) tags |  Ryan MadO

# %%
# Plot a scatter plot for 'hour_watched'
plt.scatter(twitch_vs_game_data_df['avg_hours_watched'], twitch_vs_game_data_df['review_avg_percent'], color='blue')
plt.title('Hours Wacthed vs. Review Percentages')
plt.xlabel('Hours Watched')
plt.ylabel('Review Percentages')

# Show the plot
plt.show()

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
sns.scatterplot(x='avg_hours_watched', y='avg_hours_streamed', data=twitch_vs_game_data_df)
sns.regplot(x='avg_hours_watched', y='avg_hours_streamed', data=twitch_vs_game_data_df, scatter=False, color='red') # Adds a trend line

plt.title('Relationship between Hours Watched and Hours Streamed on Twitch.tv')
plt.xlabel('Hours Watched')
plt.ylabel('Hours Streamed')
plt.show()

# %%
twitch_vs_game_data_df['avg_hours_watched'].value_counts(bins= 10)
# Out:
# (29932.225, 6496131.4]      841
# (6496131.4, 12898308.8]      10
# (12898308.8, 19300486.2]      6
# (25702663.6, 32104841.0]      1
# (38507018.4, 44909195.8]      1
# (44909195.8, 51311373.2]      1
# (51311373.2, 57713550.6]      1
# (57713550.6, 64115728.0]      1
# (19300486.2, 25702663.6]      0
# (32104841.0, 38507018.4]      0
# Name: count, dtype: int64

# %%
# Plotting the histogram
plt.figure(figsize=(10, 6))
sns.histplot(twitch_vs_game_data_df['avg_hours_watched'], bins=30, kde=False, color='skyblue')
plt.title('Distribution of Hours Watched')
plt.xlabel('Hours Watched')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Sort 'avg_hours_watched' from highest to lowest values
twitch_vs_game_data_df = twitch_vs_game_data_df.sort_values(by='avg_hours_watched', ascending=False)
twitch_vs_game_data_df.head(50)
# Out:
#                                   title  avg_hours_watched  \
# 302                  Grand Theft Auto V           64115728
# 127                      Counter-Strike           53172684
# 128    Counter-Strike: Global Offensive           48489362
# 198                              Dota 2           42350161
# 233                             FIFA 22           28608284
# 343                     Hogwarts Legacy           16842526
# 497                            Only Up!           16039966
# 36                             Among Us           15849833
# 59                      Baldur's Gate 3           15671913
# 163                    Dead by Daylight           13545274
# 238        Fall Guys: Ultimate Knockout           13006660
# 597                                Rust           10434473
# 517                 PUBG: BATTLEGROUNDS            9725767
# 482                           New World            9582426
# 543  Power Rangers: Battle for the Grid            8091268
# 581               Resident Evil Village            8070879
# 622                                Sifu            7868018
# 723                          The Quarry            7658431
# 174                           Destiny 2            7174193
# 571                          Remnant II            6976623
# 475                            NBA 2K21            6662712
# 64                 BattleBit Remastered            6292272
# 213                          ELDEN RING            6275674
# 416                           Loop Hero            6219389
# 57                         Back 4 Blood            6077030
# 577                     Resident Evil 3            5788535
# 792                            V Rising            5418040
# 526                        Phasmophobia            5356910
# 48            Assassin's Creed Valhalla            5353420
# 140                           DEATHLOOP            5285183
# 463                         MultiVersus            5163589
# 147              DRAGON BALL Z: KAKAROT            5108815
# 661                               Stray            5091275
# 446                  Minecraft Dungeons            5090928
# 139                      Cyberpunk 2077            5069059
# 836             Wolcen: Lords of Mayhem            4926745
# 474                            NBA 2K20            4911758
# 835             Wo Long: Fallen Dynasty            4841739
# 476                            NBA 2K22            4789599
# 776                      Twelve Minutes            4709086
# 565         Ratchet & Clank: Rift Apart            4702938
# 76                         Black Desert            4642169
# 477                            NBA 2K23            4180801
# 794                             Valheim            4095888
# 371           Internet Cafe Simulator 2            4014396
# 52                         Atomic Heart            3998058
# 33                     Amnesia: Rebirth            3963640
# 608                               Scorn            3937538
# 121                   Contraband Police            3905618
# 681                      Tales of Arise            3887606
#
#      avg_hours_streamed  avg_streamers  avg_viewers  avg_channels   app_id  \
# 302             1123643         126038        87926          1539   271590
# 127              913781         141632        72571          1248       10
# 128              906847         123006        66604          1243      730
# 198              509145          36145        58036           697      570
# 233              665236         123516        39228           911  1506830
# 343              978880         121568        24875          1423   990080
# 497              134777          42445        22078           183  2381590
# 36               296428          68944        21747           406   945360
# 59               556982          43456        21198           758  1086940
# 163              738369          68595        18559          1011   381210
# 238              354073          73442        17675           482  1097150
# 597              183374          18355        14292           251   252490
# 517              495358          47808        13337           679   578080
# 482              258221          17509        13057           351  1063730
# 543                8678            995        10889            11  1110100
# 581              294413          34485        10899           397  1196590
# 622              148649          37354        11725           221  2138710
# 723              108576          18869        10588           148  1577120
# 174              565819          53869         9832           775  1085660
# 571              283087          32813         9389           380  1282100
# 475              561472          52794         9161           771  1225330
# 64               146138          27123         8577           198   671860
# 213              334744          48378         8704           463  1245620
# 416               96115          12397         8370           129  1282730
# 57               232005          38193         8202           313   924970
# 577              162507          24811         8022           224   952060
# 792              142018          16353         7327           192  1604030
# 526              365595          72134         7322           500   739630
# 48               256689          26200         7408           354  2208920
# 140               87875          11199         7350           122  1252330
# 463              230586          79612         6970           311  1818750
# 147              163319          20528         6924           223   851850
# 661              231389          65421         6851           311  1332010
# 446              252266          41560         6898           344  1672970
# 139              254519          30143         6883           346  1091500
# 836              117217          10863         7056           166   424370
# 474              372656          38292         6714           508  1089350
# 835              201263          33987         6530           270  1448440
# 476              450538          62925         6573           617  1644960
# 776               55686          13034         6359            75  1097200
# 565              136911          14327         6540           190  1895880
# 76               130426           7702         6347           178   582660
# 477              575837          94867         5746           789  1919590
# 794              250536          23316         5821           351   892970
# 371               18589           5236         5667            25  1563180
# 52               161996          36979         5873           231   668580
# 33                63754          11206         5334            85   999220
# 608               92364          29783         5299           124   698670
# 121               28039           6492         5273            37   756800
# 681              276115          15551         5406           384   740130
#
#     release_date  reviews_total  review_avg_percent  launch_price_cents  \
# 302   2015-04-13        1322782               89.85                2999
# 127   2000-11-01         137421               97.00                 999
# 128   2012-08-21        7382695               88.00                1499
# 198   2013-07-09        2017009               82.00                2999
# 233   2021-09-30          92689               81.71                5999
# 343   2023-02-10         153204               92.00                5999
# 497   2023-05-24          10392               71.00                 799
# 36    2018-11-16         585788               92.00                 499
# 59    2020-10-06          63044               89.00                5999
# 163   2016-06-14         486959               80.00                1999
# 238   2020-08-03         389591               68.44                1999
# 597   2018-02-08         775223               87.00                3999
# 517   2017-12-21        2201296               57.00                2999
# 482   2021-09-28         221055               70.00                3999
# 543   2019-09-24           1130               87.00                1999
# 581   2021-05-06          64873               95.00                7999
# 622   2023-03-28           3326               92.00                3999
# 723   2022-06-09           5734               79.00                6999
# 174   2019-10-01         555551               82.00                3499
# 571   2023-07-25           6261               81.00                4999
# 475   2020-09-03          28226               59.18                5999
# 64    2023-06-15          63529               90.00                1499
# 213   2022-02-24         520024               92.00                5999
# 416   2021-03-04          29276               93.00                1499
# 57    2021-10-12          36130               66.00                5999
# 577   2020-04-02          48121               80.00                5999
# 792   2022-05-17          62539               88.00                1999
# 526   2020-09-18         466827               96.00                1399
# 48    2022-12-06          10386               67.00                5999
# 140   2021-09-13          16760               77.00                5999
# 463   2022-07-19          69218               86.65                3999
# 147   2020-01-16          32219               93.00                8499
# 661   2022-07-19         109121               97.00                2999
# 446   2021-09-22           7648               91.00                1999
# 139   2020-12-09         549004               80.00                5999
# 836   2020-02-13          60570               56.00                3999
# 474   2019-09-05          45766               63.92                5999
# 835   2023-03-03          17053               46.00                5999
# 476   2021-09-09          29659               58.00                5999
# 776   2021-08-19           5941               73.00                2499
# 565   2023-07-26           1109               84.00                5999
# 76    2017-05-24          48662               76.00                 999
# 477   2022-09-08          32208               64.00                5999
# 794   2021-02-02         353477               95.00                1999
# 371   2022-01-07           8663               73.00                1999
# 52    2023-02-20          18176               84.00                5999
# 33    2020-10-20           6301               77.00                2999
# 608   2022-10-14           8059               76.00                3999
# 121   2023-03-08           6737               94.00                1999
# 681   2021-09-09          22572               89.00                5999
#
#      dataset_est_rev_cents
# 302             3967023218
# 127              137283579
# 128            11066659805
# 198             6049009991
# 233              556041311
# 343              919070796
# 497                8303208
# 36               292308212
# 59               378200956
# 163              973431041
# 238              778792409
# 597             3100116777
# 517             6601686704
# 482              883998945
# 543                2258870
# 581              518919127
# 622               13300674
# 723               40132266
# 174             1943872949
# 571               31298739
# 475              169327774
# 64                95229971
# 213             3119623976
# 416               43884724
# 57               216743870
# 577              288677879
# 792              125015461
# 526              653090973
# 48                62305614
# 140              100543240
# 463              276802782
# 147              273829281
# 661              327253879
# 446               15288352
# 139             3293474996
# 836              242219430
# 474              274550234
# 835              102300947
# 476              177924341
# 776               14846559
# 565                6652891
# 76                48613338
# 477              193215792
# 794              706600523
# 371               17317337
# 52               109037824
# 33                18896699
# 608               32227941
# 121               13467263
# 681              135409428

# %%
# Create a DataFrame with the top 10 highest 'avg_hours_watched' values
top_10_df = twitch_vs_game_data_df.nlargest(10, 'avg_hours_watched')
top_10_df.head(10)
# Out:
#                                 title  avg_hours_watched  avg_hours_streamed  \
# 302                Grand Theft Auto V           64115728             1123643
# 127                    Counter-Strike           53172684              913781
# 128  Counter-Strike: Global Offensive           48489362              906847
# 198                            Dota 2           42350161              509145
# 233                           FIFA 22           28608284              665236
# 343                   Hogwarts Legacy           16842526              978880
# 497                          Only Up!           16039966              134777
# 36                           Among Us           15849833              296428
# 59                    Baldur's Gate 3           15671913              556982
# 163                  Dead by Daylight           13545274              738369
#
#      avg_streamers  avg_viewers  avg_channels   app_id release_date  \
# 302         126038        87926          1539   271590   2015-04-13
# 127         141632        72571          1248       10   2000-11-01
# 128         123006        66604          1243      730   2012-08-21
# 198          36145        58036           697      570   2013-07-09
# 233         123516        39228           911  1506830   2021-09-30
# 343         121568        24875          1423   990080   2023-02-10
# 497          42445        22078           183  2381590   2023-05-24
# 36           68944        21747           406   945360   2018-11-16
# 59           43456        21198           758  1086940   2020-10-06
# 163          68595        18559          1011   381210   2016-06-14
#
#      reviews_total  review_avg_percent  launch_price_cents  \
# 302        1322782               89.85                2999
# 127         137421               97.00                 999
# 128        7382695               88.00                1499
# 198        2017009               82.00                2999
# 233          92689               81.71                5999
# 343         153204               92.00                5999
# 497          10392               71.00                 799
# 36          585788               92.00                 499
# 59           63044               89.00                5999
# 163         486959               80.00                1999
#
#      dataset_est_rev_cents
# 302             3967023218
# 127              137283579
# 128            11066659805
# 198             6049009991
# 233              556041311
# 343              919070796
# 497                8303208
# 36               292308212
# 59               378200956
# 163              973431041

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
sns.scatterplot(x='avg_hours_watched', y='review_avg_percent', data=top_10_df)
sns.regplot(x='avg_hours_watched', y='review_avg_percent', data=top_10_df, scatter=False, color='red')  # Adds a trend line

plt.title('Relationship between Hours Watched and Game Review Percentages')
plt.xlabel('Hours Watched')
plt.ylabel('Game Review Percentages')
plt.show()

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
sns.scatterplot(x='review_avg_percent', y='avg_hours_watched', data=top_10_df)
sns.regplot(x='review_avg_percent', y='avg_hours_watched', data=top_10_df, scatter=False, color='red')  # Adds a trend line

plt.title('Relationship between Hours Watched and Game Review Percentages')
plt.xlabel('Hours Watched')
plt.ylabel('Game Review Percentages')
plt.show()

# %%
top_10_reviews_df = twitch_vs_game_data_df.nlargest(50, 'review_avg_percent')
top_10_reviews_df.head(50)
# Out:
#                                     title  avg_hours_watched  \
# 795                     Vampire Survivors            2715286
# 319                       Half-Life: Alyx            2631169
# 316                                 Hades            1721582
# 129                        Crab Champions            1660800
# 649                        Stardew Valley            1071113
# 589                              RimWorld            1064438
# 772                        Trombone Champ             931016
# 585                         Rhythm Doctor             877177
# 384                           Katana ZERO             665019
# 760     Totally Accurate Battle Simulator             503213
# 6                           A Hat in Time             331964
# 541                              Portal 2             300123
# 127                        Counter-Strike           53172684
# 661                                 Stray            5091275
# 578                       Resident Evil 4            2610602
# 86                            Bloons TD 6            1873428
# 97                                Bugsnax            1779642
# 576                       Resident Evil 2            1442945
# 367                           Inscryption            1425827
# 442                     Metal: Hellsinger            1324841
# 338                            Hi-Fi RUSH            1238104
# 626                        Slay the Spire            1178056
# 607                          Satisfactory            1131656
# 555                         Psychonauts 2            1091485
# 688                              Terraria            1059837
# 544                   PowerWash Simulator            1041649
# 212                  Dyson Sphere Program             936196
# 523                       Persona 5 Royal             920565
# 168                    Deep Rock Galactic             756740
# 221                Euro Truck Simulator 2             756459
# 345                         Hollow Knight             733038
# 522                      Persona 4 Golden             689822
# 692         The Binding of Isaac: Rebirth             650630
# 753                           Tiny Rogues             637425
# 160                            Dead Cells             609947
# 459                Mount & Blade: Warband             589235
# 518                        Papers, Please             473786
# 106                               Celeste             409971
# 407                         Left 4 Dead 2             402067
# 722                        The Pedestrian             359607
# 318                           Half-Life 2             327996
# 627                         Slime Rancher             303745
# 528  Phoenix Wright: Ace Attorney Trilogy             281404
# 190                            Dishonored             234719
# 478                       NEKOPARA Vol. 2             116412
# 526                          Phasmophobia            5356910
# 502         Ori and the Will of the Wisps            2324521
# 291                            God of War            1966502
# 683                              Teardown            1966486
# 451                         Monster Train            1789647
#
#      avg_hours_streamed  avg_streamers  avg_viewers  avg_channels   app_id  \
# 795               41655          11538         3796            57  1794680
# 319               43547           8169         3552            58   546560
# 316               74640          11508         2353           101  1145360
# 129               37349           8423         2309            51   774801
# 649               82756          13330         1467           113   413150
# 589               28659           2560         1457            38   294100
# 772                6677           3962         1294             9  1059990
# 585                8941           2906         1180            12   774181
# 384               10328           2607          924            14   460950
# 760                4394           2233          693             5   508440
# 6                 13813           2510          450            18   253230
# 541               10734           3491          409            14      620
# 127              913781         141632        72571          1248       10
# 661              231389          65421         6851           311  1332010
# 578              125080          19122         3564           170  2050650
# 86                34746           7320         2575            47   960090
# 97                25438           5013         2475            35   674140
# 576               71631          12619         1993            98   883710
# 367               41802           6845         1953            56  1092790
# 442               40926          15020         1842            56  1061910
# 338               77184          19251         1845           115  1817230
# 626               20864           3725         1621            28   646570
# 607               57311           5760         1546            78   526870
# 555               45502           6546         1469            61   607080
# 688               65352          10742         1448            89   105600
# 544               32118          10208         1420            43  1290000
# 212               33932           2919         1330            48  1366540
# 523               60687           5333         1266            82  1687950
# 168               26750           3958         1018            35   548430
# 221               77468          10652         1036           105   227300
# 345               55197           8264         1003            75   367520
# 522               62781           5337          941            85  1113000
# 692               24573           4219          898            33   250900
# 753                1966            614          886             2  2088570
# 160               20170           4916          831            27   588650
# 459                7416           1244          803             9    48700
# 518                2447            980          706             3   239030
# 106               16832           3173          572            23   504230
# 407               27224           7008          547            36      550
# 722                1245            466          517             1   466630
# 318                5562           1321          441             7      220
# 627               16971           4840          408            22   433340
# 528                2665            431          391             3   787480
# 190                6891           1891          325             9   205100
# 478                 498            135          167             0   420110
# 526              365595          72134         7322           500   739630
# 502               90908          11869         3139           123  1057090
# 291               98180          15548         2698           134  1593500
# 683               14577           3463         2735            20  1167630
# 451               19848           2184         2451            26  1102190
#
#     release_date  reviews_total  review_avg_percent  launch_price_cents  \
# 795   2022-10-20         191904                98.0                 499
# 319   2020-03-23          70666                98.0                5999
# 316   2020-09-17         212427                98.0                2499
# 129   2023-04-01          11136                98.0                 999
# 649   2016-02-26         495433                98.0                1499
# 589   2018-10-17         138460                98.0                3499
# 772   2022-09-15           6637                98.0                1499
# 585   2021-02-26          16387                98.0                1599
# 384   2019-04-18          52203                98.0                1499
# 760   2021-04-01         102100                98.0                1999
# 6     2017-10-05          37936                98.0                2999
# 541   2011-04-18         288308                98.0                 999
# 127   2000-11-01         137421                97.0                 999
# 661   2022-07-19         109121                97.0                2999
# 578   2023-03-23          54056                97.0                5999
# 86    2018-12-17         234108                97.0                1399
# 97    2022-04-28           3380                97.0                2499
# 576   2019-01-24          92283                97.0                3999
# 367   2021-10-19          87197                97.0                1999
# 442   2022-09-15           9268                97.0                2999
# 338   2023-01-25          15338                97.0                2999
# 626   2019-01-23         115269                97.0                2499
# 607   2020-06-08         117921                97.0                2999
# 555   2021-08-24           7828                97.0                5999
# 688   2011-05-16         927752                97.0                 999
# 544   2022-07-14          33707                97.0                2499
# 212   2021-01-20          64823                97.0                1999
# 523   2022-10-20          30721                97.0                5999
# 168   2020-05-13         180721                97.0                2999
# 221   2012-10-18         483444                97.0                1999
# 345   2017-02-24         266770                97.0                1499
# 522   2020-06-13          55312                97.0                1999
# 692   2014-11-04         221166                97.0                1499
# 753   2022-09-23           3116                97.0                 599
# 160   2018-08-06         116513                97.0                2499
# 459   2010-03-31         119491                97.0                1999
# 518   2013-08-08          55231                97.0                 999
# 106   2018-01-25          69963                97.0                1999
# 407   2009-11-16         564441                97.0                 999
# 722   2020-01-29           3360                97.0                1999
# 318   2004-11-16         130902                97.0                 999
# 627   2017-08-01          96765                97.0                1999
# 528   2019-04-09          17347                97.0                2999
# 190   2012-10-08          55990                97.0                 999
# 478   2016-02-19          10637                97.0                 999
# 526   2020-09-18         466827                96.0                1399
# 502   2020-03-10         106278                96.0                2999
# 291   2022-01-14          75121                96.0                4999
# 683   2022-04-21          69541                96.0                2999
# 451   2020-05-21          16396                96.0                2499
#
#      dataset_est_rev_cents
# 795               95760096
# 319              423925334
# 316              530855073
# 129               11124864
# 649              742654067
# 589              484471540
# 772                9948863
# 585               26202813
# 384               78252297
# 760              204097900
# 6                113770064
# 541              288019692
# 127              137283579
# 661              327253879
# 578              324281944
# 86               327517092
# 97                 8446620
# 576              369039717
# 367              174306803
# 442               27794732
# 338               45998662
# 626              288057231
# 607              353645079
# 555               46960172
# 688              926824248
# 544               84233793
# 212              129581177
# 523              184295279
# 168              541982279
# 221              966404556
# 345              399888230
# 522              110568688
# 692              331527834
# 753                1866484
# 160              291165987
# 459              238862509
# 518               55175769
# 106              139856037
# 407              563876559
# 722                6716640
# 318              130771098
# 627              193433235
# 528               52023653
# 190               55934010
# 478               10626363
# 526              653090973
# 502              318727722
# 291              375529879
# 683              208553459
# 451               40973604

# %%
# Plotting the data
plt.figure(figsize=(10, 6))
sns.scatterplot(x='avg_hours_watched', y='review_avg_percent', data=top_10_reviews_df)
sns.regplot(x='avg_hours_watched', y='review_avg_percent', data=top_10_reviews_df, scatter=False, color='red')  # Adds a trend line

plt.title('Relationship between Hours Watched and Game Review Percentages')
plt.xlabel('Hours Watched')
plt.ylabel('Game Review Percentages')
plt.show()

# %%
top_10_streamed_df = twitch_vs_game_data_df.nlargest(10, 'avg_hours_streamed')
top_10_streamed_df.head(10)
# Out:
#                                 title  avg_hours_watched  avg_hours_streamed  \
# 302                Grand Theft Auto V           64115728             1123643
# 343                   Hogwarts Legacy           16842526              978880
# 127                    Counter-Strike           53172684              913781
# 128  Counter-Strike: Global Offensive           48489362              906847
# 163                  Dead by Daylight           13545274              738369
# 233                           FIFA 22           28608284              665236
# 477                          NBA 2K23            4180801              575837
# 174                         Destiny 2            7174193              565819
# 475                          NBA 2K21            6662712              561472
# 59                    Baldur's Gate 3           15671913              556982
#
#      avg_streamers  avg_viewers  avg_channels   app_id release_date  \
# 302         126038        87926          1539   271590   2015-04-13
# 343         121568        24875          1423   990080   2023-02-10
# 127         141632        72571          1248       10   2000-11-01
# 128         123006        66604          1243      730   2012-08-21
# 163          68595        18559          1011   381210   2016-06-14
# 233         123516        39228           911  1506830   2021-09-30
# 477          94867         5746           789  1919590   2022-09-08
# 174          53869         9832           775  1085660   2019-10-01
# 475          52794         9161           771  1225330   2020-09-03
# 59           43456        21198           758  1086940   2020-10-06
#
#      reviews_total  review_avg_percent  launch_price_cents  \
# 302        1322782               89.85                2999
# 343         153204               92.00                5999
# 127         137421               97.00                 999
# 128        7382695               88.00                1499
# 163         486959               80.00                1999
# 233          92689               81.71                5999
# 477          32208               64.00                5999
# 174         555551               82.00                3499
# 475          28226               59.18                5999
# 59           63044               89.00                5999
#
#      dataset_est_rev_cents
# 302             3967023218
# 343              919070796
# 127              137283579
# 128            11066659805
# 163              973431041
# 233              556041311
# 477              193215792
# 174             1943872949
# 475              169327774
# 59               378200956

# %%
# Plotting the data
plt.figure(figsize=(12, 8))
sns.scatterplot(x='avg_hours_streamed', y='review_avg_percent', data=top_10_streamed_df)
sns.regplot(x='avg_hours_streamed', y='review_avg_percent', data=top_10_streamed_df, scatter=False, color='red')  # Adds a trend line

# Annotate each point with a line and the title
for i in range(top_10_streamed_df.shape[0]):
    # Get the x and y values
    x = top_10_streamed_df['avg_hours_streamed'].iloc[i]
    y = top_10_streamed_df['review_avg_percent'].iloc[i]
    
    # Annotate with a line and text
    plt.annotate(
        top_10_streamed_df['title'].iloc[i], 
        xy=(x, y), 
        xytext=(x + 1e5, y + 1),  # Offset the text position
        fontsize=9,
        arrowprops=dict(arrowstyle='-', color='gray', lw=0.5),  # Draw a line from the point to the text
        ha='left'
    )

plt.title('Relationship between Hours Streamed and Game Review Percentages')
plt.xlabel('Hours Streamed')
plt.ylabel('Game Review Percentages')
plt.show()
